# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import weather_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
csv_path = "Resources/Homework_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for city in cities: 
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        record= record + 1
        time.sleep(1.01)
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163ecdb60c77eb643f11300d70c681ba&q=ponta do sol
# Processing Record 2 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163ecdb60c77eb643f11300d70c681ba&q=saint-philippe
# City not found. Skipping...
# Processing Record 3 | Danshui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163ecdb60c77eb643f11300d70c681ba&q=danshui
# Processing Record 4 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163ecdb60c77eb643f11300d70c681ba&q=longyearbyen
# Processing Record 5 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163ecdb60c77eb643f11300d70c681ba&q=hilo
# Processing Record 6 | Lashio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163ecdb60c77eb643f11300d70c681ba&q=lashio
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

weather_data = pd.DataFrame(weatherpy_dict)
weather_data.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
weather_data.to_csv("Resources/weather_data.csv")
weather_data.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Ponta do Sol           0      BR  1562887714        58 -20.63  -46.00
# 1  Saint-Philippe          90      CA  1562887524       100  45.36  -73.48
# 2         Danshui          20      CN  1562887717        89  22.81  114.46
# 3    Longyearbyen          75      NO  1562887718        81  78.22   15.63
# 4            Hilo          40      US  1562887560        54  19.71 -155.08
#
#    Max Temp  Wind Speed
# 0     56.57        2.84
# 1     80.60        3.36
# 2     86.00       13.42
# 3     42.80       14.99
# 4     84.20       11.41

# %%
#This code intent to remove errors with humidity > 100%
weather_data = weather_data.loc[weather_data["Humidity"]<=100]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)
plt.title("City Latitude vs. Max Temperature (07/11/19)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Max_Temp_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)
plt.title("City Latitude vs. Humidity (07/11/19")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)
plt.title("City Latitude vs. Cloudiness (07/11/19")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Cloudiness_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)
plt.title("City Latitude vs. Wind Speed (07/11/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("WindSpeed_vs_Latitude.png")
plt.show()

# %% [markdown]
# # My Analysis
#
# 1. In general, the closer the city is to latitude 0 (Ecuador), the higher the temperature.
# 2. Cities between -20 to -40 and 20 to 40 seem to have less humidity.
# 3. It does not seem to be a pattern on cloudiness and wind speed in relation to latitude of the city.
